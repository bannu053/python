# %% [markdown]
# <a href="https://colab.research.google.com/github/bannu053/python/blob/main/Python_day1_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class student:
  student_data=[]
  def __init__(self, student_id, student_name, student_age, course, marks):
        self.student_id = student_id
        self.student_name = student_name
        self.student_age = student_age
        self.course = course
        self.marks = marks

  def add_student():
    student_id = int(input("Enter student id:"))
    student_name = input("Enter student name:")
    student_age = int(input("Enter age:"))
    course = input("Enter course:")
    marks = int(input("Enter marks:"))
    new_student=student(student_id, student_name, student_age, course, marks)
    student.student_data.append(new_student)
    print("student added successfully!")


  def view_student():
    print("\n----------------------------------------------")

    if len(student.student_data) == 0:
          print("No student records found.")
          return

    print(f"{'ID':<8}{'Name':<12}{'Age':<6}{'Course':<10}{'Marks':<6}")
    print("----------------------------------------------")

      # Iterating through students list
    for i in student.student_data:
          print(f"{i.student_id:<8}{i.student_name:<12}{i.student_age:<6}{i.course:<10}{i.marks:<6}")

    print("----------------------------------------------")

  def search_student():
    print("----------------------------------------------")
    id=int(input("Enter Student id:"))
    for i in student.student_data:
      if id==i.student_id:
            print("\nStudent Found")
            print("--------------------")
            print("ID:", i.student_id)
            print("Name:", i.student_name)
            print("Age:", i.student_age)
            print("Course:", i.course)
            print("Marks:", i.marks)
            return
      print("\n not found")

    def update_student():





# -------------------------------
# Main Menu
# -------------------------------

while True:
    print("\n----------------------------------------------")
    print("       Student Management System")
    print("----------------------------------------------")

    print("""
        1. Add Student
        2. View All Students
        3. Search Student
        4. Update Student
        5. Delete Student
        6. Exit
        """)

    # storing choice into a variable ; to work with match
    choice=int(input("Enter your choice:"))
    match choice:
      case 1:
        student.add_student()
      case 2:
        student.view_student()
      case 3:
        student.search_student()
      case 4:
        student.update_student()
# Out:
# ----------------------------------------------
#        Student Management System
# ----------------------------------------------
#
#         1. Add Student
#         2. View All Students
#         3. Search Student
#         4. Update Student
#         5. Delete Student
#         6. Exit
#
# Enter your choice:1
# Enter student id:11
# Enter student name:11111
# Enter age:11
# Enter course:11
# Enter marks:11
# student added successfully!
#
# ----------------------------------------------
#        Student Management System
# ----------------------------------------------
#
#         1. Add Student
#         2. View All Students
#         3. Search Student
#         4. Update Student
#         5. Delete Student
#         6. Exit
#
# Enter your choice:3
# ----------------------------------------------
# Enter Student id:11
#
# Student Found
# --------------------
# ID: 11
# Name: 11111
# Age: 11
# Course: 11
# Marks: 11
#
# ----------------------------------------------
# ...
